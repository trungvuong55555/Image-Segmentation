# %%
# !nvidia-smi
# Out:
# Sat Nov 27 11:31:58 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P0    56W / 149W |   1167MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
from skimage import io

from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.python.keras import Sequential
from tensorflow.keras import layers, optimizers
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint, LearningRateScheduler
import tensorflow.keras.backend as K
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose, Concatenate, Input
from tensorflow.keras.applications import VGG19

from warnings import filterwarnings
filterwarnings('ignore')

import random

import glob
from IPython.display import display

# %%
df = pd.read_csv('/content/drive/MyDrive/kaggle_3m/infor_image.csv')

# %%
from sklearn.model_selection import train_test_split
df_train, df_test = train_test_split(df, test_size=0.15)
df_train, df_val = train_test_split(df_train, test_size=0.15)
print(df_train.values.shape)
print(df_val.values.shape)
print(df_test.values.shape)
# Out:
# (1417, 3)
# (251, 3)
# (295, 3)

# %%
def train_generator(data_frame, batch_size, aug_dict,
        image_color_mode="rgb",
        mask_color_mode="grayscale",
        image_save_prefix="image",
        mask_save_prefix="mask",
        save_to_dir=None,
        target_size=(256,256),
        seed=1):

    image_datagen = ImageDataGenerator(**aug_dict)
    mask_datagen = ImageDataGenerator(**aug_dict)
    
    image_generator = image_datagen.flow_from_dataframe(
        data_frame,
        x_col = "image_path",
        class_mode = None,
        color_mode = image_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix  = image_save_prefix,
        seed = seed)

    mask_generator = mask_datagen.flow_from_dataframe(
        data_frame,
        x_col = "mask_path",
        class_mode = None,
        color_mode = mask_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix  = mask_save_prefix,
        seed = seed)

    train_gen = zip(image_generator, mask_generator)
    
    for (img, mask) in train_gen:
        img, mask = adjust_data(img, mask)
        yield (img,mask)

def adjust_data(img,mask):
    img = img / 255.
    mask = mask / 255.
    mask[mask > 0.5] = 1
    mask[mask <= 0.5] = 0
    
    return (img, mask)

# %%
smooth=100

def dice_coef(y_true, y_pred):
    y_true = K.flatten(y_true)
    y_pred = K.flatten(y_pred)
    intersection = K.sum(y_true * y_pred)
    union = K.sum(y_true) + K.sum(y_pred)
    return (2.0 * intersection + smooth) / (union + smooth)

def dice_coef_loss(y_true, y_pred):
    return 1 - dice_coef(y_true, y_pred)

def bce_dice_loss(y_true, y_pred):
    bce = tf.keras.losses.BinaryCrossentropy(from_logits=True)
    return dice_coef_loss(y_true, y_pred) + bce(y_true, y_pred)

def iou(y_true, y_pred):
    intersection = K.sum(y_true * y_pred)
    sum_ = K.sum(y_true + y_pred)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return jac

# %%
IMAGE_SIZE = (256, 256)

# %%
def conv_block(input, num_filters):
    x = Conv2D(num_filters, 3, padding="same")(input)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(num_filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    return x

def decoder_block(input, skip_features, num_filters):
    x = Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(input)
    x = Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x

def build_vgg19_unet(input_shape):
    """ Input """
    inputs = Input(input_shape)

    """ Pre-trained VGG19 Model """
    vgg19 = VGG19(include_top=False, weights="imagenet", input_tensor=inputs)

    """ Encoder """
    s1 = vgg19.get_layer("block1_conv2").output         
    s2 = vgg19.get_layer("block2_conv2").output         
    s3 = vgg19.get_layer("block3_conv4").output         
    s4 = vgg19.get_layer("block4_conv4").output         

    """ Bridge """
    b1 = vgg19.get_layer("block5_conv4").output         

    """ Decoder """
    d1 = decoder_block(b1, s4, 512)                     
    d2 = decoder_block(d1, s3, 256)                     
    d3 = decoder_block(d2, s2, 128)                    
    d4 = decoder_block(d3, s1, 64)                      

    """ Output """
    outputs = Conv2D(1, 1, padding="same", activation="sigmoid")(d4)

    model = Model(inputs, outputs, name="VGG19_U-Net")
    return model

model = build_vgg19_unet((256,256,3))
model.summary()
# Out:
# Model: "VGG19_U-Net"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  block1_conv1 (Conv2D)          (None, 256, 256, 64  1792        ['input_5[0][0]']
#                                 )
#
#  block1_conv2 (Conv2D)          (None, 256, 256, 64  36928       ['block1_conv1[0][0]']
#                                 )
#
#  block1_pool (MaxPooling2D)     (None, 128, 128, 64  0           ['block1_conv2[0][0]']
#                                 )
#
#  block2_conv1 (Conv2D)          (None, 128, 128, 12  73856       ['block1_pool[0][0]']
#                                 8)
#
#  block2_conv2 (Conv2D)          (None, 128, 128, 12  147584      ['block2_conv1[0][0]']
#                                 8)
#
#  block2_pool (MaxPooling2D)     (None, 64, 64, 128)  0           ['block2_conv2[0][0]']
#
#  block3_conv1 (Conv2D)          (None, 64, 64, 256)  295168      ['block2_pool[0][0]']
#
#  block3_conv2 (Conv2D)          (None, 64, 64, 256)  590080      ['block3_conv1[0][0]']
#
#  block3_conv3 (Conv2D)          (None, 64, 64, 256)  590080      ['block3_conv2[0][0]']
#
#  block3_conv4 (Conv2D)          (None, 64, 64, 256)  590080      ['block3_conv3[0][0]']
#
#  block3_pool (MaxPooling2D)     (None, 32, 32, 256)  0           ['block3_conv4[0][0]']
#
#  block4_conv1 (Conv2D)          (None, 32, 32, 512)  1180160     ['block3_pool[0][0]']
#
#  block4_conv2 (Conv2D)          (None, 32, 32, 512)  2359808     ['block4_conv1[0][0]']
#
#  block4_conv3 (Conv2D)          (None, 32, 32, 512)  2359808     ['block4_conv2[0][0]']
#
#  block4_conv4 (Conv2D)          (None, 32, 32, 512)  2359808     ['block4_conv3[0][0]']
#
#  block4_pool (MaxPooling2D)     (None, 16, 16, 512)  0           ['block4_conv4[0][0]']
#
#  block5_conv1 (Conv2D)          (None, 16, 16, 512)  2359808     ['block4_pool[0][0]']
#
#  block5_conv2 (Conv2D)          (None, 16, 16, 512)  2359808     ['block5_conv1[0][0]']
#
#  block5_conv3 (Conv2D)          (None, 16, 16, 512)  2359808     ['block5_conv2[0][0]']
#
#  block5_conv4 (Conv2D)          (None, 16, 16, 512)  2359808     ['block5_conv3[0][0]']
#
#  conv2d_transpose_16 (Conv2DTra  (None, 32, 32, 512)  1049088    ['block5_conv4[0][0]']
#  nspose)
#
#  concatenate_16 (Concatenate)   (None, 32, 32, 1024  0           ['conv2d_transpose_16[0][0]',
#                                 )                                 'block4_conv4[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 32, 32, 512)  4719104     ['concatenate_16[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 32, 32, 512)  2048       ['conv2d_36[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 32, 32, 512)  0           ['batch_normalization_32[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 32, 32, 512)  2359808     ['activation_32[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 32, 32, 512)  2048       ['conv2d_37[0][0]']
#  ormalization)
#
#  activation_33 (Activation)     (None, 32, 32, 512)  0           ['batch_normalization_33[0][0]']
#
#  conv2d_transpose_17 (Conv2DTra  (None, 64, 64, 256)  524544     ['activation_33[0][0]']
#  nspose)
#
#  concatenate_17 (Concatenate)   (None, 64, 64, 512)  0           ['conv2d_transpose_17[0][0]',
#                                                                   'block3_conv4[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 64, 64, 256)  1179904     ['concatenate_17[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_38[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 64, 64, 256)  0           ['batch_normalization_34[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 64, 64, 256)  590080      ['activation_34[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_39[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 64, 64, 256)  0           ['batch_normalization_35[0][0]']
#
#  conv2d_transpose_18 (Conv2DTra  (None, 128, 128, 12  131200     ['activation_35[0][0]']
#  nspose)                        8)
#
#  concatenate_18 (Concatenate)   (None, 128, 128, 25  0           ['conv2d_transpose_18[0][0]',
#                                 6)                                'block2_conv2[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 128, 128, 12  295040      ['concatenate_18[0][0]']
#                                 8)
#
#  batch_normalization_36 (BatchN  (None, 128, 128, 12  512        ['conv2d_40[0][0]']
#  ormalization)                  8)
#
#  activation_36 (Activation)     (None, 128, 128, 12  0           ['batch_normalization_36[0][0]']
#                                 8)
#
#  conv2d_41 (Conv2D)             (None, 128, 128, 12  147584      ['activation_36[0][0]']
#                                 8)
#
#  batch_normalization_37 (BatchN  (None, 128, 128, 12  512        ['conv2d_41[0][0]']
#  ormalization)                  8)
#
#  activation_37 (Activation)     (None, 128, 128, 12  0           ['batch_normalization_37[0][0]']
#                                 8)
#
#  conv2d_transpose_19 (Conv2DTra  (None, 256, 256, 64  32832      ['activation_37[0][0]']
#  nspose)                        )
#
#  concatenate_19 (Concatenate)   (None, 256, 256, 12  0           ['conv2d_transpose_19[0][0]',
#                                 8)                                'block1_conv2[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 256, 256, 64  73792       ['concatenate_19[0][0]']
#                                 )
#
#  batch_normalization_38 (BatchN  (None, 256, 256, 64  256        ['conv2d_42[0][0]']
#  ormalization)                  )
#
#  activation_38 (Activation)     (None, 256, 256, 64  0           ['batch_normalization_38[0][0]']
#                                 )
#
#  conv2d_43 (Conv2D)             (None, 256, 256, 64  36928       ['activation_38[0][0]']
#                                 )
#
#  batch_normalization_39 (BatchN  (None, 256, 256, 64  256        ['conv2d_43[0][0]']
#  ormalization)                  )
#
#  activation_39 (Activation)     (None, 256, 256, 64  0           ['batch_normalization_39[0][0]']
#                                 )
#
#  conv2d_44 (Conv2D)             (None, 256, 256, 1)  65          ['activation_39[0][0]']
#
# ==================================================================================================
# Total params: 31,172,033
# Trainable params: 31,168,193
# Non-trainable params: 3,840
# __________________________________________________________________________________________________

# %%
# Set parameters
EPOCHS = 150
BATCH_SIZE = 16
learning_rate = 1e-4

# %%
train_generator_args = dict(rotation_range=0.1,
                            width_shift_range=0.05,
                            height_shift_range=0.05,
                            shear_range=0.05,
                            zoom_range=0.05,
                            horizontal_flip=True,
                            vertical_flip=True,
                            fill_mode='nearest')
train_gen = train_generator(df_train, BATCH_SIZE,
                                train_generator_args,
                                target_size=IMAGE_SIZE)
    
val_gen = train_generator(df_val, BATCH_SIZE,
                                dict(),
                                target_size=IMAGE_SIZE)
    

opt = Adam(lr=learning_rate, beta_1=0.9, beta_2=0.999, epsilon=None, amsgrad=False)
model.compile(optimizer=opt, loss=bce_dice_loss, metrics=[iou, dice_coef])

callbacks = [ModelCheckpoint('unet_brainMRI_seg.hdf5', verbose=0, save_best_only=True),
            ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, verbose=1, min_lr=1e-11),
            EarlyStopping(monitor='val_loss', restore_best_weights=True, patience=15)]

history = model.fit(train_gen,
                    steps_per_epoch=len(df_train) / BATCH_SIZE, 
                    epochs=EPOCHS, 
                    callbacks=callbacks,
                    validation_data = val_gen,
                    validation_steps=len(df_val) / BATCH_SIZE)
# Out:
# Found 1417 validated image filenames.
# Found 1417 validated image filenames.
# Epoch 1/150
# 89/88 [==============================] - ETA: -5s - loss: 1.3190 - iou: 0.0285 - dice_coef: 0.0546Found 251 validated image filenames.
# Found 251 validated image filenames.
# 88/88 [==============================] - 1322s 15s/step - loss: 1.3190 - iou: 0.0285 - dice_coef: 0.0546 - val_loss: 1.6237 - val_iou: 0.0233 - val_dice_coef: 0.0451 - lr: 1.0000e-04
# Epoch 2/150
# 88/88 [==============================] - 142s 2s/step - loss: 1.0075 - iou: 0.0688 - dice_coef: 0.1258 - val_loss: 1.2773 - val_iou: 0.0354 - val_dice_coef: 0.0676 - lr: 1.0000e-04
# Epoch 3/150
# 88/88 [==============================] - 142s 2s/step - loss: 0.8982 - iou: 0.1080 - dice_coef: 0.1903 - val_loss: 1.0639 - val_iou: 0.0672 - val_dice_coef: 0.1233 - lr: 1.0000e-04
# Epoch 4/150
# 88/88 [==============================] - 142s 2s/step - loss: 0.8232 - iou: 0.1426 - dice_coef: 0.2437 - val_loss: 0.8400 - val_iou: 0.1343 - val_dice_coef: 0.2328 - lr: 1.0000e-04
# Epoch 5/150
# 88/88 [==============================] - 142s 2s/step - loss: 0.7641 - iou: 0.1753 - dice_coef: 0.2905 - val_loss: 0.6953 - val_iou: 0.2150 - val_dice_coef: 0.3453 - lr: 1.0000e-04
# Epoch 6/150
# 88/88 [==============================] - 142s 2s/step - loss: 0.6997 - iou: 0.2157 - dice_coef: 0.3453 - val_loss: 0.6714 - val_iou: 0.2274 - val_dice_coef: 0.3593 - lr: 1.0000e-04
# Epoch 7/150
# 88/88 [==============================] - 142s 2s/step - loss: 0.6394 - iou: 0.2557 - dice_coef: 0.3974 - val_loss: 0.5772 - val_iou: 0.2984 - val_dice_coef: 0.4490 - lr: 1.0000e-04
# Epoch 8/150
# 88/88 [==============================] - 142s 2s/step - loss: 0.5844 - iou: 0.2977 - dice_coef: 0.4491 - val_loss: 0.5420 - val_iou: 0.3346 - val_dice_coef: 0.4896 - lr: 1.0000e-04
# Epoch 9/150
# 88/88 [==============================] - 141s 2s/step - loss: 0.5442 - iou: 0.3330 - dice_coef: 0.4854 - val_loss: 0.8925 - val_iou: 0.1308 - val_dice_coef: 0.2278 - lr: 1.0000e-04
# Epoch 10/150
# 88/88 [==============================] - 141s 2s/step - loss: 0.4939 - iou: 0.3758 - dice_coef: 0.5329 - val_loss: 0.5448 - val_iou: 0.3447 - val_dice_coef: 0.5066 - lr: 1.0000e-04
# Epoch 11/150
# 88/88 [==============================] - 142s 2s/step - loss: 0.4507 - iou: 0.4179 - dice_coef: 0.5754 - val_loss: 0.4269 - val_iou: 0.4417 - val_dice_coef: 0.5946 - lr: 1.0000e-04
# Epoch 12/150
# 88/88 [==============================] - 142s 2s/step - loss: 0.4109 - iou: 0.4543 - dice_coef: 0.6120 - val_loss: 0.3727 - val_iou: 0.5029 - val_dice_coef: 0.6532 - lr: 1.0000e-04
# Epoch 13/150
# 88/88 [==============================] - 142s 2s/step - loss: 0.3840 - iou: 0.4852 - dice_coef: 0.6389 - val_loss: 0.3335 - val_iou: 0.5255 - val_dice_coef: 0.6835 - lr: 1.0000e-04
# Epoch 14/150
# 88/88 [==============================] - 140s 2s/step - loss: 0.3473 - iou: 0.5205 - dice_coef: 0.6729 - val_loss: 0.4801 - val_iou: 0.3894 - val_dice_coef: 0.5504 - lr: 1.0000e-04
# Epoch 15/150
# 88/88 [==============================] - 140s 2s/step - loss: 0.3181 - iou: 0.5545 - dice_coef: 0.7009 - val_loss: 0.3903 - val_iou: 0.4936 - val_dice_coef: 0.6502 - lr: 1.0000e-04
# Epoch 16/150
# 88/88 [==============================] - 142s 2s/step - loss: 0.2697 - iou: 0.6007 - dice_coef: 0.7449 - val_loss: 0.2537 - val_iou: 0.6262 - val_dice_coef: 0.7623 - lr: 1.0000e-04
# Epoch 17/150
# 88/88 [==============================] - 142s 2s/step - loss: 0.2671 - iou: 0.6116 - dice_coef: 0.7484 - val_loss: 0.2486 - val_iou: 0.6367 - val_dice_coef: 0.7687 - lr: 1.0000e-04
# Epoch 18/150
# 88/88 [==============================] - 142s 2s/step - loss: 0.2358 - iou: 0.6460 - dice_coef: 0.7800 - val_loss: 0.2226 - val_iou: 0.6701 - val_dice_coef: 0.7944 - lr: 1.0000e-04
# Epoch 19/150
# 88/88 [==============================] - 140s 2s/step - loss: 0.2551 - iou: 0.6255 - dice_coef: 0.7613 - val_loss: 0.2454 - val_iou: 0.6392 - val_dice_coef: 0.7698 - lr: 1.0000e-04
# Epoch 20/150
# 88/88 [==============================] - 141s 2s/step - loss: 0.2306 - iou: 0.6549 - dice_coef: 0.7846 - val_loss: 0.2380 - val_iou: 0.6470 - val_dice_coef: 0.7811 - lr: 1.0000e-04
# Epoch 21/150
# 88/88 [==============================] - 140s 2s/step - loss: 0.2379 - iou: 0.6517 - dice_coef: 0.7778 - val_loss: 0.2836 - val_iou: 0.6091 - val_dice_coef: 0.7341 - lr: 1.0000e-04
# Epoch 22/150
# 88/88 [==============================] - 142s 2s/step - loss: 0.2005 - iou: 0.6924 - dice_coef: 0.8131 - val_loss: 0.2096 - val_iou: 0.6788 - val_dice_coef: 0.8031 - lr: 1.0000e-04
# Epoch 23/150
# 88/88 [==============================] - 142s 2s/step - loss: 0.1830 - iou: 0.7193 - dice_coef: 0.8291 - val_loss: 0.1756 - val_iou: 0.7284 - val_dice_coef: 0.8376 - lr: 1.0000e-04
# Epoch 24/150
# 88/88 [==============================] - 142s 2s/step - loss: 0.1686 - iou: 0.7318 - dice_coef: 0.8403 - val_loss: 0.1457 - val_iou: 0.7681 - val_dice_coef: 0.8660 - lr: 1.0000e-04
# Epoch 25/150
# 88/88 [==============================] - 140s 2s/step - loss: 0.1943 - iou: 0.7034 - dice_coef: 0.8204 - val_loss: 0.1497 - val_iou: 0.7612 - val_dice_coef: 0.8622 - lr: 1.0000e-04
# Epoch 26/150
# 88/88 [==============================] - 141s 2s/step - loss: 0.1981 - iou: 0.7022 - dice_coef: 0.8157 - val_loss: 0.1663 - val_iou: 0.7359 - val_dice_coef: 0.8424 - lr: 1.0000e-04
# Epoch 27/150
# 88/88 [==============================] - 142s 2s/step - loss: 0.1816 - iou: 0.7225 - dice_coef: 0.8324 - val_loss: 0.1401 - val_iou: 0.7728 - val_dice_coef: 0.8697 - lr: 1.0000e-04
# Epoch 28/150
# 88/88 [==============================] - 142s 2s/step - loss: 0.1703 - iou: 0.7350 - dice_coef: 0.8416 - val_loss: 0.1294 - val_iou: 0.7935 - val_dice_coef: 0.8837 - lr: 1.0000e-04
# Epoch 29/150
# 88/88 [==============================] - 140s 2s/step - loss: 0.1811 - iou: 0.7269 - dice_coef: 0.8318 - val_loss: 0.2098 - val_iou: 0.6934 - val_dice_coef: 0.8038 - lr: 1.0000e-04
# Epoch 30/150
# 88/88 [==============================] - 141s 2s/step - loss: 0.1719 - iou: 0.7352 - dice_coef: 0.8410 - val_loss: 0.3205 - val_iou: 0.5779 - val_dice_coef: 0.7105 - lr: 1.0000e-04
# Epoch 31/150
# 88/88 [==============================] - 140s 2s/step - loss: 0.2008 - iou: 0.7014 - dice_coef: 0.8156 - val_loss: 0.3209 - val_iou: 0.5551 - val_dice_coef: 0.6996 - lr: 1.0000e-04
# Epoch 32/150
# 88/88 [==============================] - 140s 2s/step - loss: 0.2169 - iou: 0.6882 - dice_coef: 0.8002 - val_loss: 0.1441 - val_iou: 0.7753 - val_dice_coef: 0.8698 - lr: 1.0000e-04
# Epoch 33/150
# 89/88 [==============================] - ETA: 0s - loss: 0.1329 - iou: 0.7842 - dice_coef: 0.8773
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 88/88 [==============================] - 140s 2s/step - loss: 0.1329 - iou: 0.7842 - dice_coef: 0.8773 - val_loss: 0.1378 - val_iou: 0.7802 - val_dice_coef: 0.8743 - lr: 1.0000e-04
# Epoch 34/150
# 88/88 [==============================] - 141s 2s/step - loss: 0.1294 - iou: 0.7912 - dice_coef: 0.8806 - val_loss: 0.1367 - val_iou: 0.7810 - val_dice_coef: 0.8747 - lr: 1.0000e-05
# Epoch 35/150
# 88/88 [==============================] - 140s 2s/step - loss: 0.1334 - iou: 0.7864 - dice_coef: 0.8765 - val_loss: 0.1357 - val_iou: 0.7834 - val_dice_coef: 0.8763 - lr: 1.0000e-05
# Epoch 36/150
# 88/88 [==============================] - 141s 2s/step - loss: 0.1291 - iou: 0.7899 - dice_coef: 0.8803 - val_loss: 0.1530 - val_iou: 0.7621 - val_dice_coef: 0.8598 - lr: 1.0000e-05
# Epoch 37/150
# 88/88 [==============================] - 142s 2s/step - loss: 0.1216 - iou: 0.8010 - dice_coef: 0.8877 - val_loss: 0.1196 - val_iou: 0.8062 - val_dice_coef: 0.8904 - lr: 1.0000e-05
# Epoch 38/150
# 88/88 [==============================] - 141s 2s/step - loss: 0.1307 - iou: 0.7882 - dice_coef: 0.8788 - val_loss: 0.1229 - val_iou: 0.8024 - val_dice_coef: 0.8888 - lr: 1.0000e-05
# Epoch 39/150
# 88/88 [==============================] - 140s 2s/step - loss: 0.1254 - iou: 0.7954 - dice_coef: 0.8835 - val_loss: 0.1267 - val_iou: 0.7939 - val_dice_coef: 0.8837 - lr: 1.0000e-05
# Epoch 40/150
# 88/88 [==============================] - 141s 2s/step - loss: 0.1247 - iou: 0.7966 - dice_coef: 0.8847 - val_loss: 0.1258 - val_iou: 0.8002 - val_dice_coef: 0.8875 - lr: 1.0000e-05
# Epoch 41/150
# 88/88 [==============================] - 140s 2s/step - loss: 0.1209 - iou: 0.8009 - dice_coef: 0.8874 - val_loss: 0.1283 - val_iou: 0.7944 - val_dice_coef: 0.8825 - lr: 1.0000e-05
# Epoch 42/150
# 89/88 [==============================] - ETA: 0s - loss: 0.1218 - iou: 0.8009 - dice_coef: 0.8874
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 88/88 [==============================] - 141s 2s/step - loss: 0.1218 - iou: 0.8009 - dice_coef: 0.8874 - val_loss: 0.1356 - val_iou: 0.7863 - val_dice_coef: 0.8748 - lr: 1.0000e-05
# Epoch 43/150
# 88/88 [==============================] - 142s 2s/step - loss: 0.1231 - iou: 0.7976 - dice_coef: 0.8845 - val_loss: 0.1173 - val_iou: 0.8087 - val_dice_coef: 0.8926 - lr: 1.0000e-06
# Epoch 44/150
# 88/88 [==============================] - 141s 2s/step - loss: 0.1179 - iou: 0.8052 - dice_coef: 0.8901 - val_loss: 0.1388 - val_iou: 0.7797 - val_dice_coef: 0.8745 - lr: 1.0000e-06
# Epoch 45/150
# 88/88 [==============================] - 142s 2s/step - loss: 0.1254 - iou: 0.7984 - dice_coef: 0.8839 - val_loss: 0.1151 - val_iou: 0.8126 - val_dice_coef: 0.8954 - lr: 1.0000e-06
# Epoch 46/150
# 88/88 [==============================] - 141s 2s/step - loss: 0.1287 - iou: 0.7942 - dice_coef: 0.8807 - val_loss: 0.1827 - val_iou: 0.7312 - val_dice_coef: 0.8191 - lr: 1.0000e-06
# Epoch 47/150
# 88/88 [==============================] - 140s 2s/step - loss: 0.1284 - iou: 0.7961 - dice_coef: 0.8807 - val_loss: 0.1355 - val_iou: 0.7864 - val_dice_coef: 0.8766 - lr: 1.0000e-06
# Epoch 48/150
# 88/88 [==============================] - 141s 2s/step - loss: 0.1234 - iou: 0.7992 - dice_coef: 0.8860 - val_loss: 0.1351 - val_iou: 0.7846 - val_dice_coef: 0.8765 - lr: 1.0000e-06
# Epoch 49/150
# 88/88 [==============================] - 140s 2s/step - loss: 0.1234 - iou: 0.7993 - dice_coef: 0.8860 - val_loss: 0.1311 - val_iou: 0.7871 - val_dice_coef: 0.8782 - lr: 1.0000e-06
# Epoch 50/150
# 89/88 [==============================] - ETA: 0s - loss: 0.1224 - iou: 0.8002 - dice_coef: 0.8867
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
# 88/88 [==============================] - 141s 2s/step - loss: 0.1224 - iou: 0.8002 - dice_coef: 0.8867 - val_loss: 0.1397 - val_iou: 0.7801 - val_dice_coef: 0.8703 - lr: 1.0000e-06
# Epoch 51/150
# 88/88 [==============================] - 140s 2s/step - loss: 0.1187 - iou: 0.8056 - dice_coef: 0.8903 - val_loss: 0.1504 - val_iou: 0.7692 - val_dice_coef: 0.8604 - lr: 1.0000e-07
# Epoch 52/150
# 88/88 [==============================] - 141s 2s/step - loss: 0.1233 - iou: 0.7996 - dice_coef: 0.8859 - val_loss: 0.1260 - val_iou: 0.7975 - val_dice_coef: 0.8854 - lr: 1.0000e-07
# Epoch 53/150
# 88/88 [==============================] - 141s 2s/step - loss: 0.1278 - iou: 0.7937 - dice_coef: 0.8817 - val_loss: 0.1161 - val_iou: 0.8148 - val_dice_coef: 0.8961 - lr: 1.0000e-07
# Epoch 54/150
# 88/88 [==============================] - 141s 2s/step - loss: 0.1239 - iou: 0.7979 - dice_coef: 0.8851 - val_loss: 0.1315 - val_iou: 0.7895 - val_dice_coef: 0.8805 - lr: 1.0000e-07
# Epoch 55/150
# 88/88 [==============================] - 142s 2s/step - loss: 0.1189 - iou: 0.8057 - dice_coef: 0.8904 - val_loss: 0.1057 - val_iou: 0.8271 - val_dice_coef: 0.9044 - lr: 1.0000e-07
# Epoch 56/150
# 88/88 [==============================] - 141s 2s/step - loss: 0.1243 - iou: 0.7979 - dice_coef: 0.8848 - val_loss: 0.1275 - val_iou: 0.7967 - val_dice_coef: 0.8851 - lr: 1.0000e-07
# Epoch 57/150
# 88/88 [==============================] - 140s 2s/step - loss: 0.1172 - iou: 0.8070 - dice_coef: 0.8915 - val_loss: 0.1229 - val_iou: 0.8037 - val_dice_coef: 0.8892 - lr: 1.0000e-07
# Epoch 58/150
# 88/88 [==============================] - 141s 2s/step - loss: 0.1187 - iou: 0.8048 - dice_coef: 0.8900 - val_loss: 0.1267 - val_iou: 0.7963 - val_dice_coef: 0.8836 - lr: 1.0000e-07
# Epoch 59/150
# 88/88 [==============================] - 141s 2s/step - loss: 0.1257 - iou: 0.7946 - dice_coef: 0.8822 - val_loss: 0.1131 - val_iou: 0.8189 - val_dice_coef: 0.8989 - lr: 1.0000e-07
# Epoch 60/150
# 89/88 [==============================] - ETA: 0s - loss: 0.1190 - iou: 0.8042 - dice_coef: 0.8898
# Epoch 00060: ReduceLROnPlateau reducing learning rate to 1.0000000116860975e-08.
# 88/88 [==============================] - 141s 2s/step - loss: 0.1190 - iou: 0.8042 - dice_coef: 0.8898 - val_loss: 0.1299 - val_iou: 0.7867 - val_dice_coef: 0.8780 - lr: 1.0000e-07
# Epoch 61/150
# 88/88 [==============================] - 140s 2s/step - loss: 0.1293 - iou: 0.7937 - dice_coef: 0.8799 - val_loss: 0.1270 - val_iou: 0.7952 - val_dice_coef: 0.8842 - lr: 1.0000e-08
# Epoch 62/150
# 88/88 [==============================] - 141s 2s/step - loss: 0.1252 - iou: 0.7972 - dice_coef: 0.8841 - val_loss: 0.1348 - val_iou: 0.7833 - val_dice_coef: 0.8752 - lr: 1.0000e-08
# Epoch 63/150
# 88/88 [==============================] - 141s 2s/step - loss: 0.1217 - iou: 0.8014 - dice_coef: 0.8876 - val_loss: 0.1120 - val_iou: 0.8199 - val_dice_coef: 0.8995 - lr: 1.0000e-08
# Epoch 64/150
# 88/88 [==============================] - 141s 2s/step - loss: 0.1219 - iou: 0.8016 - dice_coef: 0.8873 - val_loss: 0.1193 - val_iou: 0.8067 - val_dice_coef: 0.8918 - lr: 1.0000e-08
# Epoch 65/150
# 89/88 [==============================] - ETA: 0s - loss: 0.1327 - iou: 0.7890 - dice_coef: 0.8767
# Epoch 00065: ReduceLROnPlateau reducing learning rate to 9.999999939225292e-10.
# 88/88 [==============================] - 140s 2s/step - loss: 0.1327 - iou: 0.7890 - dice_coef: 0.8767 - val_loss: 0.1229 - val_iou: 0.8037 - val_dice_coef: 0.8894 - lr: 1.0000e-08
# Epoch 66/150
# 88/88 [==============================] - 141s 2s/step - loss: 0.1225 - iou: 0.7995 - dice_coef: 0.8859 - val_loss: 0.1337 - val_iou: 0.7909 - val_dice_coef: 0.8780 - lr: 1.0000e-09
# Epoch 67/150
# 88/88 [==============================] - 140s 2s/step - loss: 0.1219 - iou: 0.8012 - dice_coef: 0.8870 - val_loss: 0.1322 - val_iou: 0.7896 - val_dice_coef: 0.8787 - lr: 1.0000e-09
# Epoch 68/150
# 88/88 [==============================] - 141s 2s/step - loss: 0.1191 - iou: 0.8050 - dice_coef: 0.8899 - val_loss: 0.1413 - val_iou: 0.7723 - val_dice_coef: 0.8684 - lr: 1.0000e-09
# Epoch 69/150
# 88/88 [==============================] - 141s 2s/step - loss: 0.1324 - iou: 0.7915 - dice_coef: 0.8764 - val_loss: 0.1210 - val_iou: 0.8069 - val_dice_coef: 0.8906 - lr: 1.0000e-09
# Epoch 70/150
# 89/88 [==============================] - ETA: 0s - loss: 0.1245 - iou: 0.8001 - dice_coef: 0.8848
# Epoch 00070: ReduceLROnPlateau reducing learning rate to 9.999999717180686e-11.
# 88/88 [==============================] - 141s 2s/step - loss: 0.1245 - iou: 0.8001 - dice_coef: 0.8848 - val_loss: 0.1253 - val_iou: 0.8004 - val_dice_coef: 0.8875 - lr: 1.0000e-09

# %%
plt.figure(figsize=(8,15))
plt.subplot(3,1,1)
plt.plot(model.history.history['loss'], 'b-', label='train_loss')
plt.plot(model.history.history['val_loss'], 'r-', label='val_loss')
plt.legend(loc='best')
plt.title('Loss')

plt.subplot(3,1,2)
plt.plot(model.history.history['iou'], 'b-', label='train_iou')
plt.plot(model.history.history['val_iou'], 'r-', label='val_iou')
plt.legend(loc='best')
plt.title('IoU')

plt.subplot(3,1,3)
plt.plot(model.history.history['dice_coef'], 'b-', label='train_dice_coef')
plt.plot(model.history.history['val_dice_coef'], 'r-', label='val_dice_coef')
plt.legend(loc='best')
plt.title('Dice Coef')
# Out:
# Text(0.5, 1.0, 'Dice Coef')

# %%
test_gen = train_generator(df_test, BATCH_SIZE,
                                dict(),
                                target_size=IMAGE_SIZE)
results = model.evaluate(test_gen, steps=len(df_test) / BATCH_SIZE)
print("Test IOU: ",results[1])
print("Test Dice Coefficent: ",results[2])
# Out:
# Found 295 validated image filenames.
# Found 295 validated image filenames.
# 18/18 [==============================] - 223s 13s/step - loss: 0.1249 - iou: 0.7956 - dice_coef: 0.8845
# Test IOU:  0.7956034541130066
# Test Dice Coefficent:  0.8845288157463074

# %%
history.model.save_weights("/content/drive/MyDrive/kaggle_3m/model1.h5")
model_json = history.model.to_json()
with open("/content/drive/MyDrive/kaggle_3m/model1.json", "w") as json_file:
    json_file.write(model_json)

# %%
from keras.models import model_from_json
json_file = open('/content/drive/MyDrive/kaggle_3m/model1.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
clf = model_from_json(loaded_model_json)
clf.load_weights("/content/drive/MyDrive/kaggle_3m/model1.h5")

# %%
for i in range(30):
    index=np.random.randint(1,len(df_test.index))
    img = cv2.imread(df_test['image_path'].iloc[index])
    img = cv2.resize(img ,IMAGE_SIZE)
    img = img / 255
    img = img[np.newaxis, :, :, :]
    pred=clf.predict(img)

    plt.figure(figsize=(12,12))
    plt.subplot(1,3,1)
    plt.imshow(np.squeeze(img))
    plt.title('Original Image')
    plt.subplot(1,3,2)
    plt.imshow(np.squeeze(cv2.imread(df_test['mask_path'].iloc[index])))
    plt.title('Original Mask')
    plt.subplot(1,3,3)
    plt.imshow(np.squeeze(pred) > .5)
    plt.title('Prediction')
    plt.show()
